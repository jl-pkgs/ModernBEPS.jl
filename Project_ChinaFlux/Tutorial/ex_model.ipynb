# %%
using Revise
using BEPS

# %%
VegType = "EBF"
SoilType = "clay"
model = ParamBEPS(VegType, SoilType)
# Out:
# ParamBEPS{Float64}, N = 5
#   dz	: {Vector{Float64}} [0.05, 0.1, 0.2, 0.4, 1.25]
#   r_drainage	: {Float64} 0.5
#   ψ_min	: {Float64} 10.0
#   alpha	: {Float64} 1.5
# ------------------------------------------------------------
# Hydraulic: ParamSoilHydraulicLayers{Float64, 5}
#   θ_vfc: Array{Float64}((5,)) [0.4, 0.4, 0.4, 0.4, 0.4]
#   θ_vwp: Array{Float64}((5,)) [0.27, 0.27, 0.27, 0.27, 0.27]
#   θ_sat: Array{Float64}((5,)) [0.475, 0.475, 0.475, 0.475, 0.475]
#   K_sat: Array{Float64}((5,)) [0.0612, 0.05508, 0.04896, 0.03672, 0.01224]
#   ψ_sat: Array{Float64}((5,)) [0.37, 0.38, 0.39, 0.4, 0.42]
#   b: Array{Float64}((5,)) [7.6, 7.8, 8.0, 8.2, 8.4]
# ------------------------------------------------------------
# Thermal: ParamSoilThermalLayers{Float64, 5}
#   κ_dry: Array{Float64}((5,)) [4.4, 4.4, 4.4, 4.4, 4.4]
#   ρ_soil: Array{Float64}((5,)) [1300.0, 1500.0, 1517.0, 1517.0, 1517.0]
#   V_SOM: Array{Float64}((5,)) [0.05, 0.02, 0.01, 0.01, 0.003]
# ...

# %%
parameters(model)
# Out:
# 62×5 DataFrame
#  Row │ path                        name        value    type      bound
#      │ Array…                      Symbol      Float64  DataType  Tuple…
# ─────┼─────────────────────────────────────────────────────────────────────────
#    1 │ Any[:r_drainage]            r_drainage   0.5     Float64   (0.2, 0.7)
#    2 │ Any[:hydraulic, :θ_vfc, 1]  θ_vfc        0.4     Float64   (0.1, 0.45)
#    3 │ Any[:hydraulic, :θ_vfc, 2]  θ_vfc        0.4     Float64   (0.1, 0.45)
#    4 │ Any[:hydraulic, :θ_vfc, 3]  θ_vfc        0.4     Float64   (0.1, 0.45)
#    5 │ Any[:hydraulic, :θ_vfc, 4]  θ_vfc        0.4     Float64   (0.1, 0.45)
#    6 │ Any[:hydraulic, :θ_vfc, 5]  θ_vfc        0.4     Float64   (0.1, 0.45)
#    7 │ Any[:hydraulic, :θ_vwp, 1]  θ_vwp        0.27    Float64   (0.02, 0.3)
#    8 │ Any[:hydraulic, :θ_vwp, 2]  θ_vwp        0.27    Float64   (0.02, 0.3)
#   ⋮  │             ⋮                   ⋮          ⋮        ⋮           ⋮
# ...

# %%
parameters(model.veg)
# Out:
# 16×5 DataFrame
#  Row │ path             name          value    type      bound
#      │ Array…           Symbol        Float64  DataType  Tuple…
# ─────┼─────────────────────────────────────────────────────────────────
#    1 │ [:LAI_max_o]     LAI_max_o      4.5     Float64   (0.1, 7.0)
#    2 │ [:LAI_max_u]     LAI_max_u      2.4     Float64   (0.1, 7.0)
#    3 │ [:α_canopy_vis]  α_canopy_vis   0.04    Float64   (0.02, 0.15)
#    4 │ [:α_canopy_nir]  α_canopy_nir   0.25    Float64   (0.15, 0.5)
#    5 │ [:α_soil_sat]    α_soil_sat     0.1     Float64   (0.05, 0.2)
#    6 │ [:α_soil_dry]    α_soil_dry     0.35    Float64   (0.2, 0.5)
#    7 │ [:r_root_decay]  r_root_decay   0.95    Float64   (0.85, 0.999)
#    8 │ [:Ω]             Ω              0.85    Float64   (0.3, 1.0)
#    9 │ [:z_canopy_o]    z_canopy_o    23.0     Float64   (0.1, 50.0)
#   10 │ [:z_canopy_u]    z_canopy_u     3.0     Float64   (0.05, 5.0)
# ...

# %%
SoilTypes
# Out:
# 11-element Vector{String}:
#  "sand"
#  "loamy_sand"
#  "sandy_loam"
#  "loam"
#  "silty_loam"
#  "sandy_clay_loam"
#  "clay_loam"
#  "silty_clay_loam"
#  "sandy_clay"
#  "silty_clay"
#  "clay"

# %%
VegTypes
# Out:
# 8-element Vector{String}:
#  "ENF"
#  "DNF"
#  "DBF"
#  "EBF"
#  "Shrub-SH"
#  "CRO"
#  "C4"
#  "default"
